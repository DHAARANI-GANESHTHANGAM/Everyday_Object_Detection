# %% [markdown]
# <a href="https://colab.research.google.com/github/DHAARANI-GANESHTHANGAM/Everyday_Object_Detection/blob/main/notebooks/04_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install -q ultralytics

import sys
sys.path.append("/content/drive/MyDrive/Everyday_Object_Detection")
from eval_utils import *
print("Ready:", PROJECT)
# Out:
# Mounted at /content/drive
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 75.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 kB 9.3 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# Ready: /content/drive/MyDrive/Everyday_Object_Detection

# %%
from ultralytics import YOLOWorld

world = YOLOWorld("yolov8s-worldv2.pt")
world.set_classes([c.lower() for c in CLASSES])   # same order as the dataset
evaluate_and_log(world, "v0", "Zero-shot YOLO-World v2 (no training)")
regression_check("v0")
# Out:
# ...
# requirements: Ultralytics requirement ['git+https://github.com/ultralytics/CLIP.git'] not found, attempting AutoUpdate...
# Using Python 3.13.15 environment at: /usr
# Resolved 37 packages in 1.16s
# Prepared 2 packages in 4.26s
# Installed 2 packages in 1ms
#  + clip==1.0 (from git+https://github.com/ultralytics/CLIP.git@a13192f8cb767260d7dfd98c843b0716593169e7)
#  + ftfy==6.3.1
#
# requirements: AutoUpdate success ✅ 5.9s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
# 100%|████████████████████████████████████████| 338M/338M [00:01<00:00, 212MiB/s]
# ...
# Ultralytics 8.4.162 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8s-worldv2 summary (fused): 236 layers, 164,026,601 parameters, 151,277,313 gradients, 31.9 GFLOPs
# ...
